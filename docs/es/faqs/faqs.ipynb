# %% [markdown]
# # Preguntas frecuentes

# %% [markdown]
# Bienvenido a las preguntas frecuentes de `pydap`. Puedes inspeccionar las preguntas actuales en el navegador de la izquierda. Si no ves una pregunta que tienes, no dudes en abrir un issue en el [issue tracker](https://github.com/pydap/pydap/issues) de Github.
